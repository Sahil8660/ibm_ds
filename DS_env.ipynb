# %% [markdown]
# # My Jupyter Notebook on IBM Watson Studio

# %% [markdown]
# **Sahil Khan**

# %% [markdown]
# *I am interested in Data Science because it has many categorie to explore and I love exploring data regarding health and Medication*

# %% [markdown]
# Converting 200 minutes into hours

# %%
minutes = 200
hours = minutes/60
print(hours)
# Out:
# [1] 3.333333

# %% [markdown]
# The Languages Data Science has :
# 1. Python
# 2. C++
# 3. Java
